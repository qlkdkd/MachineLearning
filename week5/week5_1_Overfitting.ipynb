# %% [markdown]
# ## Ungraded Lab: Overfitting
#
# <img align="left" src="./images/C1_W3_Overfitting_a.png"     style=" width:250px; padding: 10px; " >
# <img align="left" src="./images/C1_W3_Overfitting_b.png"     style=" width:250px; padding: 10px; " >
# <img  src="./images/C1_W3_Overfitting_c.png"     style=" width:250px; padding: 10px; " >
#
# ### Goals
# 이 실습에서는 다음을 살펴봅니다.
# * 과적합이 발생할 수 있는 상황
# * 몇 가지 해결책

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from ipywidgets import Output
from plt_overfit import overfit_example, output
plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# ### Overfitting
#
# 이번주 강의에서는 과적합이 발생할 수 있는 상황을 설명했습니다. 아래 셀을 실행하여 과적합을 탐색할 수 있는 플롯을 생성하십시오. 셀 아래에 추가 지침이 있습니다.

# %%
plt.close("all")
display(output)
ofit=overfit_example(False)
# Out:
# Output()
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# 위의 플롯에서 다음을 수행할 수 있습니다.
#
# * 회귀 및 분류 예제 간 전환
# * 데이터 추가
# * 모델의 차수(degree)를 선택
# * 모델을 데이터에 맞추다
# 시도해 볼만한 몇 가지 사항은 다음과 같습니다.
#
# * 차수(degree) = 1로 데이터를 맞춥니다. '미적합(underfitting)'에 주목하세요.
# * 차수(degree) = 6으로 데이터를 맞춥니다. '과적합(overfitting)'에 주목하세요.
# * '최적의 핏'을 얻기 위한 차수 조정
# * 데이터 추가:
#     * 극단적인 예는 과적합을 증가시킬 수 있습니다(이상값이라고 가정).
#     * 명목(nominal) 예제는 과적합을 줄일 수 있습니다.
# * '회귀'와 '범주형' 사이를 전환하여 두 가지 예를 모두 시도해 보세요.
# 플롯을 재설정하려면 셀을 다시 실행하십시오. 다음 클릭을 하기 전에 플롯이 업데이트되도록 천천히 클릭하십시오.
#
# 구현에 대한 참고 사항:
#
# * '이상적인' 곡선은 데이터 세트를 달성하기 위해 노이즈가 추가된 생성기 모델을 나타냅니다.
# * 'fit'은 속도를 향상시키기 위해 순수한 경사하강법을 사용하지 않습니다. 이러한 방법은 더 작은 데이터 세트에 사용할 수 있습니다.
